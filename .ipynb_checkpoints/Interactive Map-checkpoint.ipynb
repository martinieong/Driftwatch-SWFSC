# %%
import requests
import SPOT_API
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
#!pip install folium
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
#!pip install -U folium

# %%
locationdf = SPOT_API.access_XML_API()

# %%
locationdf['Latitude'] = pd.to_numeric(locationdf['Latitude'])
locationdf['Longitude'] = pd.to_numeric(locationdf['Longitude'])
locationdf
# Out:
#    MessengerName  Latitude  Longitude
# 0              E  32.77713 -117.19247
# 1              E  32.77716 -117.19252
# 2              A  32.77713 -117.19243
# 3              A  32.77714 -117.19244
# 4              A  32.77717 -117.19244
# 5              A  32.77712 -117.19243
# 6              A  32.77718 -117.19254
# 7              A  32.77714 -117.19254
# 8              E  32.77718 -117.19254
# 9              A  32.77718 -117.19247
# 10             A  32.77717 -117.19247
# 11             A  32.77721 -117.19247
# 12             A  32.77714 -117.19247
# 13             A  32.77714 -117.19247
# 14             A  32.77718 -117.19247
# 15             A  32.77709 -117.19244
# 16             E  32.77714 -117.19254
# 17             A  32.77713 -117.19244
# 18             E  32.77716 -117.19237
# 19             A  32.77715 -117.19241
# 20             A  32.77712 -117.19243
# 21             A  32.77717 -117.19249
# 22             E  32.77715 -117.19247
# 23             A  32.77714 -117.19243
# 24             E  32.77714 -117.19252
# 25             A  32.77715 -117.19243
# 26             A  32.77718 -117.19249
# 27             E  32.77713 -117.19252
# 28             A  32.77718 -117.19249
# 29             E  32.77713 -117.19252
# 30             A  32.77714 -117.19247
# 31             E  32.77709 -117.19243
# 32             E  32.77726 -117.19260
# 33             E  32.77714 -117.19247
# 34             A  32.77711 -117.19247
# 35             E  32.77715 -117.19247
# 36             A  32.77715 -117.19254
# 37             E  32.77715 -117.19247
# 38             A  32.77715 -117.19247
# 39             E  32.77721 -117.19244
# 40             A  32.77712 -117.19249
# 41             E  32.77721 -117.19244
# 42             A  32.77715 -117.19247
# 43             A  32.77726 -117.19247
# 44             A  32.77713 -117.19247
# 45             A  32.77723 -117.19243
# 46             E  32.77717 -117.19244
# 47             A  32.77719 -117.19243
# 48             A  32.77708 -117.19244
# 49             E  32.77713 -117.19249

# %%
from folium import plugins
map_center = (np.mean(locationdf['Latitude']),np.mean(locationdf['Longitude']))
m = folium.Map(location = map_center, zoom_start = 12)

# mcg = folium.plugins.MarkerCluster(control=False)
# m.add_child(mcg)

g1 = plugins.FeatureGroupSubGroup(fg, 'Spot Device A')
m.add_child(g1)

g2 = plugins.FeatureGroupSubGroup(fg, 'Spot Device E')
m.add_child(g2)

pathA=[]
pathE=[]

for i in locationdf.iterrows():
    if i[1]['MessengerName'] == 'A':
        pathA.append(([i[1]['Latitude'],i[1]['Longitude']]))
        folium.Marker(
            location = [i[1]['Latitude'],i[1]['Longitude']]).add_to(g1)
    elif i[1]['MessengerName'] == 'E':
        pathE.append(([i[1]['Latitude'],i[1]['Longitude']]))        
        folium.Marker(
            location = [i[1]['Latitude'],i[1]['Longitude']]).add_to(g2)    
        
m.add_child(fg)

folium.LayerControl(collapsed=False).add_to(m)


#Path of Device A  
folium.PolyLine(locations = [pathA], 
                line_opacity = 0.3).add_to(m) 

#Path of Device E
folium.PolyLine(locations = [pathE], 
                line_opacity = 0.3).add_to(m)

m
##TODO Movement Speed, thesis, automate for multiple devices ############
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
set(locationdf.MessengerName)
# Out:
# {'A', 'E'}

# %%
###Experimental to automate

from folium import plugins
map_center = (np.mean(locationdf['Latitude']),np.mean(locationdf['Longitude']))
m = folium.Map(location = map_center, zoom_start = 12)

messengers = []
groups = []
paths=dict()
# mcg = folium.plugins.MarkerCluster(control=False)
# m.add_child(mcg)
for i in set(locationdf.MessengerName):
    groups.append(plugins.FeatureGroupSubGroup(fg, f'Spot Device {i}'))
    messengers.append(f'{i}')
    paths[i] = []
    #groups[f'{i}'] = plugins.FeatureGroupSubGroup(fg, f'Spot Device {i}')                  

    
set(locationdf.MessengerName)
groups
# Out:
# [<folium.plugins.feature_group_sub_group.FeatureGroupSubGroup at 0x1dd44791cc0>,
#  <folium.plugins.feature_group_sub_group.FeatureGroupSubGroup at 0x1dd459f9c18>]

# %%
                      
for i in locationdf.iterrows():
    paths[i[1]['MessengerName']].append(([i[1]['Latitude'],i[1]['Longitude']]))
    folium.Marker(
             location = [i[1]['Latitude'],i[1]['Longitude']]).add_to(groups[list(set(locationdf.MessengerName)).index(i[1]['MessengerName'])])


m.add_child(fg)
for item in range(len(groups)):
    m.add_child(groups[item])
    
folium.LayerControl(collapsed=False).add_to(m)



# #Path of Device A  
for i in paths:
    folium.PolyLine(locations = paths[i], 
                     line_opacity = 0.3).add_to(m) 

#     folium.Marker(
#              location = [i[1]['Latitude'],i[1]['Longitude']]).add_to(groups[list(set(locationdf.MessengerName)).index(i[1]['MessengerName'])])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
